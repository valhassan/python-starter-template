# %% [markdown]
# # How I would setup my enviroment for ML in 2025

# %% [markdown]
# **The primary tools**
#
# Core
# - Python: This remains the programming language of choice of Machine Learning Scientists.
#
# - UV: Super fast python enviroment manager built on Rust.
#
# <br>
#
#
#
# Development
# - IDE: Development environment that greatly reduces frustration when writing your code. Feel free to use VIM or any editor, I admire your courage.
#
# - Ruff: Super fast python linter and code formatter also written in Rust.
#
# - Git and Github: Version control and cloud code repository (Public and Private).
#
# <br>
#
# Machine learning | Deep Learning | Artificial Intelligence
# - Pytorch: Deep learning framework that provides routines for manipulating tensors (the holy grail of machine learning) + math operations.
#
# - Lightning: Adds lightning and thunder to pytorch; provides high level abstraction to pytorch making your life somewhat easier.

# %% [markdown]
# ### Installing Python
#
# There are different ways python can be downloaded and installed
#
# 1. Python can be installed independently and system wide across most OS.
# https://www.python.org/downloads/
#
# 2. Python can be installed in an isolated enviroment. (Recommended)
#     - using enviroments managers such as conda, uv, virtualenv
#
#
# A simple command to check python version
# ```
# python --version
#
# ```

# %% [markdown]
# ### Installing UV
#
# There are different ways UV can be installed
#
# - Standalone Installer
#
# - PyPi
#
# https://docs.astral.sh/uv/getting-started/installation/#standalone-installer

# %% [markdown]
# ### Integrated Development Enviroment
#
#
# Vscode: https://code.visualstudio.com/  (Open-Source)
#
# Pycharm: https://www.jetbrains.com/pycharm/ (Free and Paid Pro Version)
#
#
# #### AI focused IDEs
# Cursor: https://cursor.com/home
#
# Windsurf: https://windsurf.com/

# %% [markdown]
# ### Using Git
#
# Download and Install
#
# https://git-scm.com/downloads
#
# - Check if Git is installed
#     ```
#     git --version
#     ```
#
# - Configure your global identity
#     ```
#     git config --global user.name "Your Name"
#     git config --global user.email "you@example.com"
#     ```
#
# - Set default branch name
#     ```
#     git config --global init.defaultBranch main
#     ```
#
# - Verify your configuration
#     ```
#     git config --list
#     ```

# %% [markdown]
# ###

# %% [markdown]
# #### Github
#
# Create an account on Github
# https://github.com
#
#
# #### Using Git and Github
#
# - Generate SSH key
#     ```
#     ssh-keygen -t ed25519 -C "vic@gmail.com"
#     ```
#
# - Start SSH agent
#     ```
#     eval "$(ssh-agent -s)"
#     ```
#
# - Add key
#     ```
#     ssh-add ~/.ssh/id_ed25519
#     ```
#
# - Copy the public key to Github
#     ```
#     cat ~/.ssh/id_ed25519.pub
#     ```
#
# - Test Github Connection
#     ```
#     ssh -T git@github.com
#     ```
#
# <br>
#
# - Coding and Versioning
#
#     1. Clone from Github
#         ```
#         git clone git@github.com:NRCan/geo-deep-learning.git
#         ```
#
#     2. Create a new repo on Github
#         ```
#         cd ~/projects
#         ```
#         ```
#         mkdir geo-deep-learning
#         ```
#         ```
#         touch README.md
#         ```
#         <br>
#
#         Intialize git
#         ```
#         git init
#         ```
#
#         Stage the file
#
#         ```
#         git add README.md
#         ```
#
#         Commit Change
#         ```
#         git commit -m "Add README"
#         ```
#
#         Add Remote and Push
#         ```
#         git remote add origin git@github.com:USERNAME/geo-deep-learning.git
#
#         git push -u origin main
#         ```
